# %%
import pandas as pd 
import numpy as np  
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
india_hr = pd.read_csv('house_rent.csv')

# %%
india_hr.head(6)
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  5/18/2022    2  10000  1100  Ground out of 2   Super Area
# 1  5/13/2022    2  20000   800       1 out of 3   Super Area
# 2  5/16/2022    2  17000  1000       1 out of 3   Super Area
# 3   7/4/2022    2  10000   800       1 out of 2   Super Area
# 4   5/9/2022    2   7500   850       1 out of 2  Carpet Area
# 5  4/29/2022    2   7000   600  Ground out of 1   Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
# 5               Thakurpukur  Kolkata       Unfurnished  Bachelors/Family
#
# ...

# %%
# check null values

india_hr.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
# datatype

india_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
india_hr.shape
# Out:
# (4746, 12)

# %% [markdown]
# ### 20 VISUALIZATION DISTRIBUTED AS FOLLOW:
#
# 1. FIVE BAR CHARTS
# 2. FIVE SCATTERD CHARTS
# 3. FIVE BOX CHARTS
# 4. ONE LINE CHART
# 5. ONE PIE CHART
# 6. ONE HISTOGRAM
# 7. ONE HEAT MAP
# 8. ONE VIOLIN MAP

# %% [markdown]
# ### BAR CHARTS

# %%
sns.barplot(data = india_hr, x = 'Furnishing Status', y = 'Rent')
plt.title('RENT vs FURNISHING STATUS', color = 'red')
# Out:
# Text(0.5, 1.0, 'RENT vs FURNISHING STATUS')

# %%
sns.barplot(data = india_hr, x = 'Area Type', y = 'Rent')
plt.title('RENT vs AREA TYPE', color = 'green')
# Out:
# Text(0.5, 1.0, 'RENT vs AREA TYPE')

# %%
sns.barplot(data = india_hr, x = 'City', y = 'Rent')
plt.title('RENT vs CITY', color = 'orange')
# Out:
# Text(0.5, 1.0, 'RENT vs CITY')

# %%
sns.barplot(data = india_hr, x = 'Area Type', y = 'Size')
plt.title('SIZE vs AREA TYPE', color = 'blue')
# Out:
# Text(0.5, 1.0, 'SIZE vs AREA TYPE')

# %%
sns.barplot(data = india_hr, x = 'Furnishing Status', y = 'Bathroom')
plt.title('BATHROOM vs FURNISHING STATUS', color = 'purple')
# Out:
# Text(0.5, 1.0, 'BATHROOM vs FURNISHING STATUS')

# %% [markdown]
# ### SCATTERD CHART

# %%
india_hr.head(3)
# Out:
#    Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  5/18/2022    2  10000  1100  Ground out of 2  Super Area
# 1  5/13/2022    2  20000   800       1 out of 3  Super Area
# 2  5/16/2022    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner

# %%
sns.scatterplot(data = india_hr,x ='Area Locality', y = 'Rent')
# Out:
# <Axes: xlabel='Area Locality', ylabel='Rent'>

# %%
sns.scatterplot(data = india_hr,x ='Area Type', y = 'BHK')
# Out:
# <Axes: xlabel='Area Type', ylabel='BHK'>

# %%
sns.scatterplot(data = india_hr,x ='Floor', y = 'Rent')
# Out:
# <Axes: xlabel='Floor', ylabel='Rent'>

# %%
sns.scatterplot(data = india_hr,x ='Tenant Preferred', y = 'BHK')
# Out:
# <Axes: xlabel='Tenant Preferred', ylabel='BHK'>

# %%
sns.scatterplot(data = india_hr,x ='City', y = 'Rent')
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %% [markdown]
# ### BOX PLOT

# %%
india_hr.head(3)
# Out:
#    Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  5/18/2022    2  10000  1100  Ground out of 2  Super Area
# 1  5/13/2022    2  20000   800       1 out of 3  Super Area
# 2  5/16/2022    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner

# %%
sns.boxplot(data = india_hr, x = 'Area Type',y = 'Bathroom')
# Out:
# <Axes: xlabel='Area Type', ylabel='Bathroom'>

# %%
sns.boxplot(data = india_hr, x = 'Area Type',y = 'Rent')
# Out:
# <Axes: xlabel='Area Type', ylabel='Rent'>

# %%
sns.boxplot(data = india_hr, x = 'Furnishing Status',y = 'Size')
# Out:
# <Axes: xlabel='Furnishing Status', ylabel='Size'>

# %%
sns.boxplot(data = india_hr, x = 'City',y = 'BHK')
# Out:
# <Axes: xlabel='City', ylabel='BHK'>

# %%
sns.boxplot(data = india_hr, x = 'Tenant Preferred',y = 'Rent')
# Out:
# <Axes: xlabel='Tenant Preferred', ylabel='Rent'>

# %% [markdown]
# ### LINE CHART

# %%
india_hr.head(5)
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  5/18/2022    2  10000  1100  Ground out of 2   Super Area
# 1  5/13/2022    2  20000   800       1 out of 3   Super Area
# 2  5/16/2022    2  17000  1000       1 out of 3   Super Area
# 3   7/4/2022    2  10000   800       1 out of 2   Super Area
# 4   5/9/2022    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
sns.lineplot(data = india_hr, x = 'City',y = 'Posted On')
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='City', ylabel='Posted On'>

# %% [markdown]
# ### HISTOGRAM

# %%
sns.histplot(data = india_hr, x = 'BHK',y = 'City')
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='BHK', ylabel='City'>

# %% [markdown]
# ### VIOLIN PLOT

# %%
sns.violinplot(data = india_hr, x = 'Bathroom', y = 'Rent')
# Out:
# <Axes: xlabel='Bathroom', ylabel='Rent'>

# %%
india_hr['Area Type'].value_counts()
# Out:
# Area Type
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: count, dtype: int64
